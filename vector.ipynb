# %%
import numpy as np

# %%
#vector x dengan ukuran 3x1
x = np.array([18, 1, 8])

# %%
#hitung panjang vector x
len(x)
# Out:
# 3

# %%
#tampilkan ukuran vector x
x.shape
# Out:
# (3,)

# %%
#tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
#akses elemen pertama dari vector x
x[0] # 0 adalah elemen pertama dalam array
# Out:
# np.int64(18)

# %%
#tampilkan tipe data elemen pertama dari vector x
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# Vector TRansposition

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([18,  1,  8])

# %%
#tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_t
y = np.array([[18, 1, 8]])
y
# Out:
# array([[18,  1,  8]])

# %%
#tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %% [markdown]
# Vector in Pythorchand Tensorflow

# %%
import torch
import tensorflow as tf

# %%
x_pt = torch.tensor([25, 2, 5])
x_pt
# Out:
# tensor([25,  2,  5])

# %%
x_tf = tf.Variable([25, 2, 5])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>
