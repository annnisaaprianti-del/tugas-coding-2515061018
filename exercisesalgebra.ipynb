# %%
import numpy as np

# %%
# membuat matriks 4 x 1
v = np.array([
    [25],
    [2],
    [-3],
    [-23]
])
print(v)

transpose = v.T

print("hasil transpose:")
print(transpose)
# Out:
# [[ 25]
#  [  2]
#  [ -3]
#  [-23]]
# hasil transpose:
# [[ 25   2  -3 -23]]

# %%
transpose = v.T
