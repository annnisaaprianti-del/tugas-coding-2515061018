# %% [markdown]
# Ortogonal Vektor

# %%
import numpy as np

# %%
#vector i dengan elemen (1,0)
i = np.array([1, 0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0, 1]) #vector j dengan elemen (0,1)
j
# Out:
# array([0, 1])

# %%
#buktikan bahwa vector i dan vector j itu orthogonal
np.dot(i, j)
# Out:
# np.int64(0)
